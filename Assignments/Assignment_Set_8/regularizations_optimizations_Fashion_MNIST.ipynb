# %% [markdown]
# # Some regularizations and optimization algorithms on [Fashion-MNIST](https://github.com/zalandoresearch/fashion-mnist)
# By [Zahra Taheri](https://github.com/zahta), November 25, 2020

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torchsummary import summary

import matplotlib as mpl
import matplotlib.pyplot as plt

import os

import warnings
warnings.filterwarnings('ignore')

# Set the seeds to ensure reproducibility
np.random.seed(1)
torch.manual_seed(1)

# %%
#Define path to the directory

path = os.getcwd()

mypath = path+"\Fashion-MNIST"

os.chdir(mypath)

print(os.getcwd())
# Out:
# C:\Users\Zahra\github\Deep_Learning_F20_Assignments\Assignments\Assignment_Set_8\Fashion-MNIST files\Fashion-MNIST

# %% [markdown]
# ## Loading Fashion-MNIST into NumPy arrays

# %%
from mlxtend.data import loadlocal_mnist

#load train_data and train_labels
train_data, train_labels= loadlocal_mnist(
        images_path='train-images-idx3-ubyte', 
        labels_path='train-labels-idx1-ubyte')
#load test_data and test_labels
test_data, test_labels= loadlocal_mnist(
        images_path='t10k-images-idx3-ubyte', 
        labels_path='t10k-labels-idx1-ubyte')

# %%
print(train_data.shape)   # 28*28=784
print(train_labels.shape)
# Out:
# (60000, 784)
# (60000,)

# %%
some_digit = train_data[11000]
some_digit_image = some_digit.reshape(28, 28)
plt.imshow(some_digit_image)#, cmap = mpl.cm.binary)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import numpy as np

PIL_image = Image.fromarray(np.uint8(some_digit_image))

# %%
plt.imshow(PIL_image)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Preparation of the dataset

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
train_data= train_data.reshape((train_data.shape[0],28,28))
test_data= test_data.reshape((test_data.shape[0],28,28))

# %%
from torch.utils.data import TensorDataset, DataLoader

tensor_x = torch.Tensor(train_data) # transform to torch tensor
tensor_y = torch.Tensor(train_labels)
tensor_y = tensor_y.type(torch.LongTensor)

train_dataset = TensorDataset(tensor_x,tensor_y) # create your dataset

# %%
tensor_x2 = torch.Tensor(test_data) # transform to torch tensor
tensor_y2 = torch.Tensor(test_labels)
tensor_y2 = tensor_y2.type(torch.LongTensor)

test_dataset = TensorDataset(tensor_x2,tensor_y2) # create your test dataset

# %%
tensor_y
# Out:
# tensor([9, 0, 0,  ..., 3, 0, 5])

# %%
#train_dataset[0]

# %% [markdown]
# ## Building Feedforward Neural Networks with PyTorch

# %%
def compute_accuracy(net, data_loader):
    correct_pred, num_examples = 0, 0
    with torch.no_grad():
        for features, targets in data_loader:
            features = features.view(-1, 28*28).to(device)
            targets = targets.to(device)
            outputs = net.forward(features)
            predicted_labels = torch.argmax(outputs, 1)
            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
        return correct_pred.float()/num_examples * 100        
            
            

def compute_loss(net, data_loader):
    curr_loss = 0.
    with torch.no_grad():
        for cnt, (features, targets) in enumerate(data_loader):
            features = features.view(-1, 28*28).to(device)
            targets = targets.to(device)
            outputs = net.forward(features)
            loss = criterion(outputs, targets)
            curr_loss += loss
        return float(curr_loss)/cnt

# %% [markdown]
# ## Regularizations (Ensemble Methods)

# %% [markdown]
# - [Ensembles: the only (almost) free Lunch in Machine Learning](https://towardsdatascience.com/ensembles-the-almost-free-lunch-in-machine-learning-91af7ebe5090)
#     - Build optimal ensembles of neural networks with PyTorch and NumPy
#
#
# - [Bagging and Dropout Learning](https://jrodthoughts.medium.com/bagging-and-dropout-learning-ae484023b0da)

# %% [markdown]
# ### Dropout: Ensemble Method Interpretation
# **Reference:** [Regularization by Sebastian Raschka](https://sebastianraschka.com/pdf/lecture-notes/stat479ss19/L10_regularization_slides.pdf)
#
# - In DL, we typically don't do regular ensembling (majority vote over a large number of networks, bagging, etc.) because it is very expensive to fit neural nets.
# - However, we know that the squared error for a prediction by a randomly selected model is larger than the squared error using an ensemble prediction (here, average over class probabilities).
# - Now, in dropout, we have a different model for each minibatch.
# - Via the minibatch iterations, we essentially sample over $M=2^h$ models, where h is the number of hidden units.
# - Restriction is that we have weight sharing over these models, which can be seen as a form of regularization.
# - During "inference" we can then average over all these models (but this is very expensive).
# - However, using the last model after training and scaling the predictions by a factor 1/(1-p) approximates the geometric mean and is much cheaper (actually, it's exactly the geometric mean if we have a linear model).
#
# ### Dropout: More Practical Tips
#
# - Don't use Dropout if your model does not overfit .
# - However, in that case above, it is then recommended to increase the capacity to make it overfit, and then use dropout to be able to use a larger capacity model (but make it not overfit).

# %% [markdown]
# ### Installing Ensemble-Pytorch package

# %%
#!git clone https://github.com/AaronX121/Ensemble-Pytorch.git

# %%
#mypath_ens = path+"\Ensemble-Pytorch"

#os.chdir(mypath_ens)

#print(os.getcwd())

# %%
#!pip install -r requirements.txt

# %%
#!python setup.py install

# %% [markdown]
# ### Model B: 3 Hidden Layers Feedforward Neural Network (ReLU Activation)

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 50
n_iters = 30000
num_epochs = n_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
# Out:
# 25

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %% [markdown]
# #### Create model class

# %%
class FeedforwardNeuralNetworkModel1(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNeuralNetworkModel1, self).__init__()
        # linear function 1: 
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        # non-linearity 1
        self.relu1 = nn.ReLU()
        
        # linear function 2: 
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        # non-linearity 2
        self.relu2 = nn.ReLU()
        
        # linear function 3: 
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        # non-linearity 3
        self.relu3 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.3)
        
        # linear function 4 (readout)
        self.fc4 = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        # linear function 1
        out = self.fc1(x)
        # non-linearity 1
        out = self.relu1(out)
        
        # linear function 2
        out = self.fc2(out)
        # non-linearity 2
        out = self.relu2(out)
        
        # linear function 3
        out = self.fc3(out)
        # non-linearity 3
        out = self.relu3(out)
        out = self.dropout2(out)
        
        #linear function 4 (readout)
        out = self.fc4(out)
        return out

# %%
#  Instantiate model class
input_dim = 28*28
output_dim = 10
hidden_dim = 100 

model = FeedforwardNeuralNetworkModel1(input_dim, hidden_dim, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FeedforwardNeuralNetworkModel1(
#   (fc1): Linear(in_features=784, out_features=100, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=100, out_features=100, bias=True)
#   (relu3): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          78,500
#               ReLU-2               [-1, 1, 100]               0
#             Linear-3               [-1, 1, 100]          10,100
#               ReLU-4               [-1, 1, 100]               0
#             Linear-5               [-1, 1, 100]          10,100
#               ReLU-6               [-1, 1, 100]               0
#            Dropout-7               [-1, 1, 100]               0
#             Linear-8                [-1, 1, 10]           1,010
# ================================================================
# Total params: 99,710
# Trainable params: 99,710
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.38
# Estimated Total Size (MB): 0.39
# ----------------------------------------------------------------

# %%
#  Instantiate loss class
criterion=nn.CrossEntropyLoss()

#  Instantiate optimizer class
learning_rate = 0.001
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/025 | Batch 000/1200 | Cost: 10.6171
# Epoch: 001/025 | Batch 500/1200 | Cost: 0.5135
# Epoch: 001/025 | Batch 1000/1200 | Cost: 0.8741
# Epoch: 001/025 Train Cost: 0.4831
# Time elapsed: 0.09 min
# Epoch: 002/025 | Batch 000/1200 | Cost: 0.7578
# Epoch: 002/025 | Batch 500/1200 | Cost: 0.6242
# Epoch: 002/025 | Batch 1000/1200 | Cost: 0.5952
# Epoch: 002/025 Train Cost: 0.4170
# Time elapsed: 0.17 min
# Epoch: 003/025 | Batch 000/1200 | Cost: 0.4579
# Epoch: 003/025 | Batch 500/1200 | Cost: 0.6028
# Epoch: 003/025 | Batch 1000/1200 | Cost: 0.3749
# Epoch: 003/025 Train Cost: 0.3869
# Time elapsed: 0.25 min
# Epoch: 004/025 | Batch 000/1200 | Cost: 0.4719
# Epoch: 004/025 | Batch 500/1200 | Cost: 0.5069
# Epoch: 004/025 | Batch 1000/1200 | Cost: 0.2200
# Epoch: 004/025 Train Cost: 0.3771
# Time elapsed: 0.34 min
# Epoch: 005/025 | Batch 000/1200 | Cost: 0.4536
# Epoch: 005/025 | Batch 500/1200 | Cost: 0.4169
# Epoch: 005/025 | Batch 1000/1200 | Cost: 0.4524
# Epoch: 005/025 Train Cost: 0.3564
# Time elapsed: 0.42 min
# Epoch: 006/025 | Batch 000/1200 | Cost: 0.4659
# Epoch: 006/025 | Batch 500/1200 | Cost: 0.3092
# Epoch: 006/025 | Batch 1000/1200 | Cost: 0.3099
# Epoch: 006/025 Train Cost: 0.3447
# Time elapsed: 0.50 min
# Epoch: 007/025 | Batch 000/1200 | Cost: 0.4076
# Epoch: 007/025 | Batch 500/1200 | Cost: 0.2212
# Epoch: 007/025 | Batch 1000/1200 | Cost: 0.3583
# Epoch: 007/025 Train Cost: 0.3337
# Time elapsed: 0.58 min
# Epoch: 008/025 | Batch 000/1200 | Cost: 0.3737
# Epoch: 008/025 | Batch 500/1200 | Cost: 0.1842
# Epoch: 008/025 | Batch 1000/1200 | Cost: 0.2760
# Epoch: 008/025 Train Cost: 0.3569
# Time elapsed: 0.66 min
# Epoch: 009/025 | Batch 000/1200 | Cost: 0.5309
# Epoch: 009/025 | Batch 500/1200 | Cost: 0.2751
# Epoch: 009/025 | Batch 1000/1200 | Cost: 0.2237
# Epoch: 009/025 Train Cost: 0.3177
# Time elapsed: 0.75 min
# Epoch: 010/025 | Batch 000/1200 | Cost: 0.3223
# Epoch: 010/025 | Batch 500/1200 | Cost: 0.2237
# Epoch: 010/025 | Batch 1000/1200 | Cost: 0.4189
# Epoch: 010/025 Train Cost: 0.3022
# Time elapsed: 0.83 min
# Epoch: 011/025 | Batch 000/1200 | Cost: 0.4494
# Epoch: 011/025 | Batch 500/1200 | Cost: 0.3300
# Epoch: 011/025 | Batch 1000/1200 | Cost: 0.2640
# Epoch: 011/025 Train Cost: 0.3041
# Time elapsed: 0.91 min
# Epoch: 012/025 | Batch 000/1200 | Cost: 0.1322
# Epoch: 012/025 | Batch 500/1200 | Cost: 0.5331
# Epoch: 012/025 | Batch 1000/1200 | Cost: 0.3365
# Epoch: 012/025 Train Cost: 0.2967
# Time elapsed: 1.00 min
# Epoch: 013/025 | Batch 000/1200 | Cost: 0.3222
# Epoch: 013/025 | Batch 500/1200 | Cost: 0.3092
# Epoch: 013/025 | Batch 1000/1200 | Cost: 0.4699
# Epoch: 013/025 Train Cost: 0.3030
# Time elapsed: 1.09 min
# Epoch: 014/025 | Batch 000/1200 | Cost: 0.2166
# Epoch: 014/025 | Batch 500/1200 | Cost: 0.2913
# Epoch: 014/025 | Batch 1000/1200 | Cost: 0.4953
# Epoch: 014/025 Train Cost: 0.2939
# Time elapsed: 1.18 min
# Epoch: 015/025 | Batch 000/1200 | Cost: 0.2690
# Epoch: 015/025 | Batch 500/1200 | Cost: 0.5438
# Epoch: 015/025 | Batch 1000/1200 | Cost: 0.1562
# Epoch: 015/025 Train Cost: 0.2831
# Time elapsed: 1.28 min
# Epoch: 016/025 | Batch 000/1200 | Cost: 0.2069
# Epoch: 016/025 | Batch 500/1200 | Cost: 0.4990
# Epoch: 016/025 | Batch 1000/1200 | Cost: 0.4866
# Epoch: 016/025 Train Cost: 0.2793
# Time elapsed: 1.38 min
# Epoch: 017/025 | Batch 000/1200 | Cost: 0.5423
# Epoch: 017/025 | Batch 500/1200 | Cost: 0.2796
# Epoch: 017/025 | Batch 1000/1200 | Cost: 0.3058
# Epoch: 017/025 Train Cost: 0.2833
# Time elapsed: 1.49 min
# Epoch: 018/025 | Batch 000/1200 | Cost: 0.2125
# Epoch: 018/025 | Batch 500/1200 | Cost: 0.4621
# Epoch: 018/025 | Batch 1000/1200 | Cost: 0.4389
# Epoch: 018/025 Train Cost: 0.2654
# Time elapsed: 1.58 min
# Epoch: 019/025 | Batch 000/1200 | Cost: 0.4169
# Epoch: 019/025 | Batch 500/1200 | Cost: 0.2251
# Epoch: 019/025 | Batch 1000/1200 | Cost: 0.2341
# Epoch: 019/025 Train Cost: 0.2731
# Time elapsed: 1.69 min
# Epoch: 020/025 | Batch 000/1200 | Cost: 0.2582
# Epoch: 020/025 | Batch 500/1200 | Cost: 0.2783
# Epoch: 020/025 | Batch 1000/1200 | Cost: 0.1435
# Epoch: 020/025 Train Cost: 0.2647
# Time elapsed: 1.78 min
# Epoch: 021/025 | Batch 000/1200 | Cost: 0.4182
# Epoch: 021/025 | Batch 500/1200 | Cost: 0.2024
# Epoch: 021/025 | Batch 1000/1200 | Cost: 0
min
# Epoch: 004/010 | Batch 000/938 | Cost: 0.5480
# Epoch: 004/010 | Batch 500/938 | Cost: 0.4322
# Epoch: 004/010 Train Cost: 0.4058
# Time elapsed: 0.90 min
# Epoch: 005/010 | Batch 000/938 | Cost: 0.2489
# Epoch: 005/010 | Batch 500/938 | Cost: 0.4844
# Epoch: 005/010 Train Cost: 0.3932
# Time elapsed: 1.14 min
# Epoch: 006/010 | Batch 000/938 | Cost: 0.1621
# Epoch: 006/010 | Batch 500/938 | Cost: 0.4372
# Epoch: 006/010 Train Cost: 0.3583
# Time elapsed: 1.38 min
# Epoch: 007/010 | Batch 000/938 | Cost: 0.4497
# Epoch: 007/010 | Batch 500/938 | Cost: 0.2473
# Epoch: 007/010 Train Cost: 0.3479
# Time elapsed: 1.58 min
# Epoch: 008/010 | Batch 000/938 | Cost: 0.4357
# Epoch: 008/010 | Batch 500/938 | Cost: 0.5712
# Epoch: 008/010 Train Cost: 0.3369
# Time elapsed: 1.79 min
# Epoch: 009/010 | Batch 000/938 | Cost: 0.5324
# Epoch: 009/010 | Batch 500/938 | Cost: 0.2947
# Epoch: 009/010 Train Cost: 0.3592
# Time elapsed: 1.98 min
# Epoch: 010/010 | Batch 000/938 | Cost: 0.3158
# Epoch: 010/010 | Batch 500/938 | Cost: 0.4909
# Epoch: 010/010 Train Cost: 0.3558
# Time elapsed: 2.16 min
# Total Training Time: 2.16 min
# Training Accuracy: 86.62
# Test Accuracy: 84.82

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ### Model D: 3 Hidden Layers Feedforward Neural Network

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 128
n_iters = 9400
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 20

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %%
input_dim = 28*28
output_dim = 10
hidden_dim1 = 256
hidden_dim2 = 128

# %% [markdown]
# #### Create model class

# %%
class FNNModel3(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, output_dim):
        
        super(FNNModel3, self).__init__()
        
        self.f1 = nn.Linear(input_dim,hidden_dim1)
        self.relu1 = nn.ReLU()
        
        self.f2 = nn.Linear(hidden_dim1,hidden_dim2)
        self.relu2 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.3)
        
        self.f3 = nn.Linear(hidden_dim2,output_dim)
        
    def forward(self, x):
        out = self.f1(x)
        out = self.relu1(out)

        out = self.f2(out)
        out = self.relu2(out)
        out = self.dropout1(out)
        
        out = self.f3(out)
        
        return out

# %%
model = FNNModel3(input_dim, hidden_dim1, hidden_dim2, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FNNModel3(
#   (f1): Linear(in_features=784, out_features=256, bias=True)
#   (relu1): ReLU()
#   (f2): Linear(in_features=256, out_features=128, bias=True)
#   (relu2): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (f3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 256]         200,960
#               ReLU-2               [-1, 1, 256]               0
#             Linear-3               [-1, 1, 128]          32,896
#               ReLU-4               [-1, 1, 128]               0
#            Dropout-5               [-1, 1, 128]               0
#             Linear-6                [-1, 1, 10]           1,290
# ================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.90
# Estimated Total Size (MB): 0.91
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()

learning_rate = 0.001
optimizer = torch.optim.Adamax(model.parameters())

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/020 | Batch 000/469 | Cost: 17.2844
# Epoch: 001/020 Train Cost: 0.4647
# Time elapsed: 0.13 min
# Epoch: 002/020 | Batch 000/469 | Cost: 0.4278
# Epoch: 002/020 Train Cost: 0.4007
# Time elapsed: 0.25 min
# Epoch: 003/020 | Batch 000/469 | Cost: 0.7549
# Epoch: 003/020 Train Cost: 0.3684
# Time elapsed: 0.41 min
# Epoch: 004/020 | Batch 000/469 | Cost: 0.3838
# Epoch: 004/020 Train Cost: 0.3562
# Time elapsed: 0.55 min
# Epoch: 005/020 | Batch 000/469 | Cost: 0.5114
# Epoch: 005/020 Train Cost: 0.3600
# Time elapsed: 0.67 min
# Epoch: 006/020 | Batch 000/469 | Cost: 0.4716
# Epoch: 006/020 Train Cost: 0.3421
# Time elapsed: 0.80 min
# Epoch: 007/020 | Batch 000/469 | Cost: 0.3855
# Epoch: 007/020 Train Cost: 0.3212
# Time elapsed: 0.92 min
# Epoch: 008/020 | Batch 000/469 | Cost: 0.2875
# Epoch: 008/020 Train Cost: 0.3236
# Time elapsed: 1.04 min
# Epoch: 009/020 | Batch 000/469 | Cost: 0.2860
# Epoch: 009/020 Train Cost: 0.2930
# Time elapsed: 1.16 min
# Epoch: 010/020 | Batch 000/469 | Cost: 0.2989
# Epoch: 010/020 Train Cost: 0.2825
# Time elapsed: 1.29 min
# Epoch: 011/020 | Batch 000/469 | Cost: 0.3094
# Epoch: 011/020 Train Cost: 0.2937
# Time elapsed: 1.41 min
# Epoch: 012/020 | Batch 000/469 | Cost: 0.3043
# Epoch: 012/020 Train Cost: 0.2812
# Time elapsed: 1.53 min
# Epoch: 013/020 | Batch 000/469 | Cost: 0.1839
# Epoch: 013/020 Train Cost: 0.2916
# Time elapsed: 1.66 min
# Epoch: 014/020 | Batch 000/469 | Cost: 0.2713
# Epoch: 014/020 Train Cost: 0.2751
# Time elapsed: 1.78 min
# Epoch: 015/020 | Batch 000/469 | Cost: 0.3545
# Epoch: 015/020 Train Cost: 0.2582
# Time elapsed: 1.90 min
# Epoch: 016/020 | Batch 000/469 | Cost: 0.2408
# Epoch: 016/020 Train Cost: 0.2682
# Time elapsed: 2.03 min
# Epoch: 017/020 | Batch 000/469 | Cost: 0.2515
# Epoch: 017/020 Train Cost: 0.2407
# Time elapsed: 2.16 min
# Epoch: 018/020 | Batch 000/469 | Cost: 0.2535
# Epoch: 018/020 Train Cost: 0.2493
# Time elapsed: 2.29 min
# Epoch: 019/020 | Batch 000/469 | Cost: 0.2642
# Epoch: 019/020 Train Cost: 0.2533
# Time elapsed: 2.41 min
# Epoch: 020/020 | Batch 000/469 | Cost: 0.3770
# Epoch: 020/020 Train Cost: 0.2399
# Time elapsed: 2.54 min
# Total Training Time: 2.54 min
# Training Accuracy: 90.63
# Test Accuracy: 87.98

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ## 8. RMSProp

# %% [markdown]
# ### Model B: 3 Hidden Layers Feedforward Neural Network (ReLU Activation)

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 50
n_iters = 30000
num_epochs = n_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
# Out:
# 25

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %% [markdown]
# #### Create model class

# %%
class FeedforwardNeuralNetworkModel1(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNeuralNetworkModel1, self).__init__()
        # linear function 1: 
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        # non-linearity 1
        self.relu1 = nn.ReLU()
        #self.dropout1 = nn.Dropout(0.3)
        
        # linear function 2: 
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        # non-linearity 2
        self.relu2 = nn.ReLU()
        
        # linear function 3: 
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        # non-linearity 3
        self.relu3 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.3)
        
        # linear function 4 (readout)
        self.fc4 = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        # linear function 1
        out = self.fc1(x)
        # non-linearity 1
        out = self.relu1(out)
        #out = self.dropout1(out)
        
        # linear function 2
        out = self.fc2(out)
        # non-linearity 2
        out = self.relu2(out)
        
        # linear function 3
        out = self.fc3(out)
        # non-linearity 3
        out = self.relu3(out)
        out = self.dropout2(out)
        
        #linear function 4 (readout)
        out = self.fc4(out)
        return out

# %%
#  Instantiate model class
input_dim = 28*28
output_dim = 10
hidden_dim = 100 

model = FeedforwardNeuralNetworkModel1(input_dim, hidden_dim, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FeedforwardNeuralNetworkModel1(
#   (fc1): Linear(in_features=784, out_features=100, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=100, out_features=100, bias=True)
#   (relu3): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          78,500
#               ReLU-2               [-1, 1, 100]               0
#             Linear-3               [-1, 1, 100]          10,100
#               ReLU-4               [-1, 1, 100]               0
#             Linear-5               [-1, 1, 100]          10,100
#               ReLU-6               [-1, 1, 100]               0
#            Dropout-7               [-1, 1, 100]               0
#             Linear-8                [-1, 1, 10]           1,010
# ================================================================
# Total params: 99,710
# Trainable params: 99,710
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.38
# Estimated Total Size (MB): 0.39
# ----------------------------------------------------------------

# %%
#  Instantiate loss class
criterion=nn.CrossEntropyLoss()

#  Instantiate optimizer class
learning_rate = 0.001
optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/025 | Batch 000/1200 | Cost: 9.9008
# Epoch: 001/025 | Batch 500/1200 | Cost: 0.4995
# Epoch: 001/025 | Batch 1000/1200 | Cost: 0.3256
# Epoch: 001/025 Train Cost: 0.5188
# Time elapsed: 0.10 min
# Epoch: 002/025 | Batch 000/1200 | Cost: 0.3108
# Epoch: 002/025 | Batch 500/1200 | Cost: 0.8537
# Epoch: 002/025 | Batch 1000/1200 | Cost: 0.7005
# Epoch: 002/025 Train Cost: 0.4060
# Time elapsed: 0.20 min
# Epoch: 003/025 | Batch 000/1200 | Cost: 0.9386
# Epoch: 003/025 | Batch 500/1200 | Cost: 0.1984
# Epoch: 003/025 | Batch 1000/1200 | Cost: 0.3070
# Epoch: 003/025 Train Cost: 0.3938
# Time elapsed: 0.29 min
# Epoch: 004/025 | Batch 000/1200 | Cost: 0.3267
# Epoch: 004/025 | Batch 500/1200 | Cost: 0.2171
# Epoch: 004/025 | Batch 1000/1200 | Cost: 0.5845
# Epoch: 004/025 Train Cost: 0.3797
# Time elapsed: 0.39 min
# Epoch: 005/025 | Batch 000/1200 | Cost: 0.4946
# Epoch: 005/025 | Batch 500/1200 | Cost: 0.4120
# Epoch: 005/025 | Batch 1000/1200 | Cost: 0.4303
# Epoch: 005/025 Train Cost: 0.3525
# Time elapsed: 0.50 min
# Epoch: 006/025 | Batch 000/1200 | Cost: 0.2271
# Epoch: 006/025 | Batch 500/1200 | Cost: 0.4216
# Epoch: 006/025 | Batch 1000/1200 | Cost: 0.4263
# Epoch: 006/025 Train Cost: 0.3629
# Time elapsed: 0.61 min
# Epoch: 007/025 | Batch 000/1200 | Cost: 0.4001
# Epoch: 007/025 | Batch 500/1200 | Cost: 0.6845
# Epoch: 007/025 | Batch 1000/1200 | Cost: 0.3366
# Epoch: 007/025 Train Cost: 0.3474
# Time elapsed: 0.77 min
# Epoch: 008/025 | Batch 000/1200 | Cost: 0.3377
# Epoch: 008/025 | Batch 500/1200 | Cost: 0.4804
# Epoch: 008/025 | Batch 1000/1200 | Cost: 0.4162
# Epoch: 008/025 Train Cost: 0.3623
# Time elapsed: 0.99 min
# Epoch: 009/025 | Batch 000/1200 | Cost: 0.2673
# Epoch: 009/025 | Batch 500/1200 | Cost: 0.4998
# Epoch: 009/025 | Batch 1000/1200 | Cost: 0.5542
# Epoch: 009/025 Train Cost: 0.3598
# Time elapsed: 1.21 min
# Epoch: 010/025 | Batch 000/1200 | Cost: 0.2842
# Epoch: 010/025 | Batch 500/1200 | Cost: 0.8990
# Epoch: 010/025 | Batch 1000/1200 | Cost: 0.1770
# Epoch: 010/025 Train Cost: 0.3629
# Time elapsed: 1.44 min
# Epoch: 011/025 | Batch 000/1200 | Cost: 0.5825
# Epoch: 011/025 | Batch 500/1200 | Cost: 0.5332
# Epoch: 011/025 | Batch 1000/1200 | Cost: 0.3744
# Epoch: 011/025 Train Cost: 0.3571
# Time elapsed: 1.66 min
# Epoch: 012/025 | Batch 000/1200 | Cost: 0.4216
# Epoch: 012/025 | Batch 500/1200 | Cost: 0.2984
# Epoch: 012/025 | Batch 1000/1200 | Cost: 0.2841
# Epoch: 012/025 Train Cost: 0.3523
# Time elapsed: 1.89 min
# Epoch: 013/025 | Batch 000/1200 | Cost: 0.3259
# Epoch: 013/025 | Batch 500/1200 | Cost: 0.2273
# Epoch: 013/025 | Batch 1000/1200 | Cost: 0.2395
# Epoch: 013/025 Train Cost: 0.3135
# Time elapsed: 2.12 min
# Epoch: 014/025 | Batch 000/1200 | Cost: 0.4722
# Epoch: 014/025 | Batch 500/1200 | Cost: 0.4381
# Epoch: 014/025 | Batch 1000/1200 | Cost: 0.3372
# Epoch: 014/025 Train Cost: 0.3315
# Time elapsed: 2.34 min
# Epoch: 015/025 | Batch 000/1200 | Cost: 0.1914
# Epoch: 015/025 | Batch 500/1200 | Cost: 0.3271
# Epoch: 015/025 | Batch 1000/1200 | Cost: 0.2267
# Epoch: 015/025 Train Cost: 0.4022
# Time elapsed: 2.57 min
# Epoch: 016/025 | Batch 000/1200 | Cost: 0.7816
# Epoch: 016/025 | Batch 500/1200 | Cost: 0.7031
# Epoch: 016/025 | Batch 1000/1200 | Cost: 0.4249
# Epoch: 016/025 Train Cost: 0.3267
# Time elapsed: 2.80 min
# Epoch: 017/025 | Batch 000/1200 | Cost: 0.2532
# Epoch: 017/025 | Batch 500/1200 | Cost: 0.4142
# Epoch: 017/025 | Batch 1000/1200 | Cost: 0.2867
# Epoch: 017/025 Train Cost: 0.4405
# Time elapsed: 3.03 min
# Epoch: 018/025 | Batch 000/1200 | Cost: 0.3843
# Epoch: 018/025 | Batch 500/1200 | Cost: 0.2615
# Epoch: 018/025 | Batch 1000/1200 | Cost: 0.3952
# Epoch: 018/025 Train Cost: 0.3291
# Time elapsed: 3.26 min
# Epoch: 019/025 | Batch 000/1200 | Cost: 0.2599
# Epoch: 019/025 | Batch 500/1200 | Cost: 0.4650
# Epoch: 019/025 | Batch 1000/1200 | Cost: 0.3478
# Epoch: 019/025 Train Cost: 0.3188
# Time elapsed: 3.49 min
# Epoch: 020/025 | Batch 000/1200 | Cost: 0.2376
# Epoch: 020/025 | Batch 500/1200 | Cost: 0.2491
# Epoch: 020/025 | Batch 1000/1200 | Cost: 0.5140
# Epoch: 020/025 Train Cost: 0.3351
# Time elapsed: 3.72 min
# Epoch: 021/025 | Batch 000/1200 | Cost: 0.6126
# Epoch: 021/025 | Batch 500/1200 | Cost: 0.3748
# Epoch: 021/025 | Batch 1000/1200 | Cost: 0.3307
# Epoch: 021/025 Train Cost: 0.3392
# Time elapsed: 3.96 min
# Epoch: 022/025 | Batch 000/1200 | Cost: 0.3018
# Epoch: 022/025 | Batch 500/1200 | Cost: 0.2144
# Epoch: 022/025 | Batch 1000/1200 | Cost: 0.4030
# Epoch: 022/025 Train Cost: 0.4296
# Time elapsed: 4.19 min
# Epoch: 023/025 | Batch 000/1200 | Cost: 0.6746
# Epoch: 023/025 | Batch 500/1200 | Cost: 0.2843
# Epoch: 023/025 | Batch 1000/1200 | Cost: 0.2817
# Epoch: 023/025 Train Cost: 0.3300
# Time elapsed: 4.42 min
# Epoch: 024/025 | Batch 000/1200 | Cost: 0.2844
# Epoch: 024/025 | Batch 500/1200 | Cost: 0.4886
# Epoch: 024/025 | Batch 1000/1200 | Cost: 0.3152
# Epoch: 024/025 Train Cost: 0.3470
# Time elapsed: 4.66 min
# Epoch: 025/025 | Batch 000/1200 | Cost: 0.2948
# Epoch: 025/025 | Batch 500/1200 | Cost: 0.5490
# Epoch: 025/025 | Batch 1000/1200 | Cost: 0.3445
# Epoch: 025/025 Train Cost: 0.3327
# Time elapsed: 4.90 min
# Total Training Time: 4.90 min
# Training Accuracy: 88.27
# Test Accuracy: 85.66

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ### Model C: 5 Hidden Layers Feedforward Neural Network

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 64
n_iters = 9400
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 10

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %%
input_dim = 28*28
output_dim = 10
hidden_dim1 = 100 
hidden_dim2 = 100 
hidden_dim3 = 200 
hidden_dim4 = 300 
hidden_dim5 = 100

# %% [markdown]
# #### Create model class

# %%
class FNNModel2(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, hidden_dim5, output_dim):
        
        super(FNNModel2, self).__init__()
        
        self.f1 = nn.Linear(input_dim,hidden_dim1)
        self.relu1 = nn.ReLU()
        
        self.f2 = nn.Linear(hidden_dim1,hidden_dim2)
        self.relu2 = nn.ReLU()
        
        self.f3 = nn.Linear(hidden_dim2,hidden_dim3)
        self.sigmoid = nn.Tanh()
        
        self.f4 = nn.Linear(hidden_dim3,hidden_dim4)
        self.relu3 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.25)
        
        self.f5 = nn.Linear(hidden_dim4,hidden_dim5)
        self.relu4 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)
        
        self.f6 = nn.Linear(hidden_dim5,output_dim)
        
    def forward(self, x):
        out = self.f1(x)
        out = self.relu1(out)

        out = self.f2(out)
        out = self.relu2(out)
        
        out = self.f3(out)
        out = self.sigmoid(out)
        
        out = self.f4(out)
        out = self.relu3(out)
        out = self.dropout1(out)
        
        out = self.f5(out)
        out = self.relu4(out)
        out = self.dropout2(out)
        
        out = self.f6(out)
        
        return out

# %%
model = FNNModel2(input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, hidden_dim5, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FNNModel2(
#   (f1): Linear(in_features=784, out_features=100, bias=True)
#   (relu1): ReLU()
#   (f2): Linear(in_features=100, out_features=100, bias=True)
#   (relu2): ReLU()
#   (f3): Linear(in_features=100, out_features=200, bias=True)
#   (sigmoid): Tanh()
#   (f4): Linear(in_features=200, out_features=300, bias=True)
#   (relu3): ReLU()
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (f5): Linear(in_features=300, out_features=100, bias=True)
#   (relu4): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (f6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 100]          78,500
#               ReLU-2               [-1, 1, 100]               0
#             Linear-3               [-1, 1, 100]          10,100
#               ReLU-4               [-1, 1, 100]               0
#             Linear-5               [-1, 1, 200]          20,200
#               Tanh-6               [-1, 1, 200]               0
#             Linear-7               [-1, 1, 300]          60,300
#               ReLU-8               [-1, 1, 300]               0
#            Dropout-9               [-1, 1, 300]               0
#            Linear-10               [-1, 1, 100]          30,100
#              ReLU-11               [-1, 1, 100]               0
#           Dropout-12               [-1, 1, 100]               0
#            Linear-13                [-1, 1, 10]           1,010
# ================================================================
# Total params: 200,210
# Trainable params: 200,210
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.76
# Estimated Total Size (MB): 0.78
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()

learning_rate = 0.01
optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/010 | Batch 000/938 | Cost: 2.2730
# Epoch: 001/010 | Batch 500/938 | Cost: 2.3005
# Epoch: 001/010 Train Cost: 2.3058
# Time elapsed: 0.13 min
# Epoch: 002/010 | Batch 000/938 | Cost: 2.2991
# Epoch: 002/010 | Batch 500/938 | Cost: 2.3004
# Epoch: 002/010 Train Cost: 2.3056
# Time elapsed: 0.26 min
# Epoch: 003/010 | Batch 000/938 | Cost: 2.3012
# Epoch: 003/010 | Batch 500/938 | Cost: 2.3015
# Epoch: 003/010 Train Cost: 2.3054
# Time elapsed: 0.40 min
# Epoch: 004/010 | Batch 000/938 | Cost: 2.3032
# Epoch: 004/010 | Batch 500/938 | Cost: 2.3085
# Epoch: 004/010 Train Cost: 2.3060
# Time elapsed: 0.54 min
# Epoch: 005/010 | Batch 000/938 | Cost: 2.3105
# Epoch: 005/010 | Batch 500/938 | Cost: 2.2948
# Epoch: 005/010 Train Cost: 2.3059
# Time elapsed: 0.68 min
# Epoch: 006/010 | Batch 000/938 | Cost: 2.3065
# Epoch: 006/010 | Batch 500/938 | Cost: 2.3052
# Epoch: 006/010 Train Cost: 2.3061
# Time elapsed: 0.85 min
# Epoch: 007/010 | Batch 000/938 | Cost: 2.2963
# Epoch: 007/010 | Batch 500/938 | Cost: 2.3028
# Epoch: 007/010 Train Cost: 2.3063
# Time elapsed: 1.05 min
# Epoch: 008/010 | Batch 000/938 | Cost: 2.3012
# Epoch: 008/010 | Batch 500/938 | Cost: 2.3093
# Epoch: 008/010 Train Cost: 2.3060
# Time elapsed: 1.36 min
# Epoch: 009/010 | Batch 000/938 | Cost: 2.3154
# Epoch: 009/010 | Batch 500/938 | Cost: 2.2976
# Epoch: 009/010 Train Cost: 2.3057
# Time elapsed: 1.81 min
# Epoch: 010/010 | Batch 000/938 | Cost: 2.2981
# Epoch: 010/010 | Batch 500/938 | Cost: 2.3022
# Epoch: 010/010 Train Cost: 2.3059
# Time elapsed: 2.29 min
# Total Training Time: 2.29 min
# Training Accuracy: 10.00
# Test Accuracy: 10.00

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ### Model D: 3 Hidden Layers Feedforward Neural Network

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 128
n_iters = 9400
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 20

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %%
input_dim = 28*28
output_dim = 10
hidden_dim1 = 256
hidden_dim2 = 128

# %% [markdown]
# #### Create model class

# %%
class FNNModel3(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, output_dim):
        
        super(FNNModel3, self).__init__()
        
        self.f1 = nn.Linear(input_dim,hidden_dim1)
        self.relu1 = nn.ReLU()
        
        self.f2 = nn.Linear(hidden_dim1,hidden_dim2)
        self.relu2 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.3)
        
        self.f3 = nn.Linear(hidden_dim2,output_dim)
        
    def forward(self, x):
        out = self.f1(x)
        out = self.relu1(out)

        out = self.f2(out)
        out = self.relu2(out)
        out = self.dropout1(out)
        
        out = self.f3(out)
        
        return out

# %%
model = FNNModel3(input_dim, hidden_dim1, hidden_dim2, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FNNModel3(
#   (f1): Linear(in_features=784, out_features=256, bias=True)
#   (relu1): ReLU()
#   (f2): Linear(in_features=256, out_features=128, bias=True)
#   (relu2): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (f3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
summary(model, (1,28*28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1               [-1, 1, 256]         200,960
#               ReLU-2               [-1, 1, 256]               0
#             Linear-3               [-1, 1, 128]          32,896
#               ReLU-4               [-1, 1, 128]               0
#            Dropout-5               [-1, 1, 128]               0
#             Linear-6                [-1, 1, 10]           1,290
# ================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.90
# Estimated Total Size (MB): 0.91
# ----------------------------------------------------------------

# %%
criterion = nn.CrossEntropyLoss()

learning_rate = 0.001
optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/020 | Batch 000/469 | Cost: 22.8726
# Epoch: 001/020 Train Cost: 0.5393
# Time elapsed: 0.08 min
# Epoch: 002/020 | Batch 000/469 | Cost: 0.6775
# Epoch: 002/020 Train Cost: 0.4049
# Time elapsed: 0.15 min
# Epoch: 003/020 | Batch 000/469 | Cost: 0.3771
# Epoch: 003/020 Train Cost: 0.3746
# Time elapsed: 0.23 min
# Epoch: 004/020 | Batch 000/469 | Cost: 0.3294
# Epoch: 004/020 Train Cost: 0.7438
# Time elapsed: 0.31 min
# Epoch: 005/020 | Batch 000/469 | Cost: 0.9107
# Epoch: 005/020 Train Cost: 0.3591
# Time elapsed: 0.38 min
# Epoch: 006/020 | Batch 000/469 | Cost: 0.3547
# Epoch: 006/020 Train Cost: 0.3595
# Time elapsed: 0.45 min
# Epoch: 007/020 | Batch 000/469 | Cost: 0.3742
# Epoch: 007/020 Train Cost: 0.3939
# Time elapsed: 0.52 min
# Epoch: 008/020 | Batch 000/469 | Cost: 0.3857
# Epoch: 008/020 Train Cost: 0.3474
# Time elapsed: 0.60 min
# Epoch: 009/020 | Batch 000/469 | Cost: 0.6419
# Epoch: 009/020 Train Cost: 0.3459
# Time elapsed: 0.68 min
# Epoch: 010/020 | Batch 000/469 | Cost: 0.3547
# Epoch: 010/020 Train Cost: 0.3454
# Time elapsed: 0.75 min
# Epoch: 011/020 | Batch 000/469 | Cost: 0.5954
# Epoch: 011/020 Train Cost: 0.3917
# Time elapsed: 0.83 min
# Epoch: 012/020 | Batch 000/469 | Cost: 0.4564
# Epoch: 012/020 Train Cost: 0.3739
# Time elapsed: 0.91 min
# Epoch: 013/020 | Batch 000/469 | Cost: 0.3281
# Epoch: 013/020 Train Cost: 0.3149
# Time elapsed: 0.99 min
# Epoch: 014/020 | Batch 000/469 | Cost: 0.3376
# Epoch: 014/020 Train Cost: 0.3159
# Time elapsed: 1.09 min
# Epoch: 015/020 | Batch 000/469 | Cost: 0.2814
# Epoch: 015/020 Train Cost: 0.3068
# Time elapsed: 1.18 min
# Epoch: 016/020 | Batch 000/469 | Cost: 0.3530
# Epoch: 016/020 Train Cost: 0.3300
# Time elapsed: 1.29 min
# Epoch: 017/020 | Batch 000/469 | Cost: 0.2847
# Epoch: 017/020 Train Cost: 0.2861
# Time elapsed: 1.42 min
# Epoch: 018/020 | Batch 000/469 | Cost: 0.3330
# Epoch: 018/020 Train Cost: 0.3652
# Time elapsed: 1.61 min
# Epoch: 019/020 | Batch 000/469 | Cost: 0.2437
# Epoch: 019/020 Train Cost: 0.3161
# Time elapsed: 1.82 min
# Epoch: 020/020 | Batch 000/469 | Cost: 0.3709
# Epoch: 020/020 Train Cost: 0.3021
# Time elapsed: 2.04 min
# Total Training Time: 2.04 min
# Training Accuracy: 88.75
# Test Accuracy: 86.03

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ## Batch normalization

# %% [markdown]
# ### Model B: 3 Hidden Layers Feedforward Neural Network (ReLU Activation)

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 50
n_iters = 30000
num_epochs = n_iters / (len(train_data) / batch_size)
num_epochs = int(num_epochs)
print(num_epochs)
# Out:
# 25

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %% [markdown]
# #### Create model class

# %%
class FeedforwardNeuralNetworkModel1(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(FeedforwardNeuralNetworkModel1, self).__init__()
        # linear function 1: 
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.BatchNorm1d2=nn.BatchNorm1d(hidden_dim)       
        self.relu1 = nn.ReLU()
        
        # linear function 2: 
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        # non-linearity 2
        self.relu2 = nn.ReLU()
        
        # linear function 3: 
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.BatchNorm1d1=nn.BatchNorm1d(hidden_dim)
        # non-linearity 3
        self.relu3 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.3)
        
        # linear function 4 (readout)
        self.fc4 = nn.Linear(hidden_dim, output_dim)
        
        
    def forward(self, x):
        # linear function 1
        out = self.fc1(x)
        out = self.BatchNorm1d2(out)
        # non-linearity 1
        out = self.relu1(out)
        #out = self.dropout1(out)
        
        # linear function 2
        out = self.fc2(out)
        
        # non-linearity 2
        out = self.relu2(out)
        
        # linear function 3
        out = self.fc3(out)
        #print(out.shape)
        out = self.BatchNorm1d1(out)
        # non-linearity 3
        out = self.relu3(out)
        out = self.dropout2(out)
        
        #linear function 4 (readout)
        out = self.fc4(out)
        return out

# %%
#  Instantiate model class
input_dim = 28*28
output_dim = 10
hidden_dim = 100 

model = FeedforwardNeuralNetworkModel1(input_dim, hidden_dim, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FeedforwardNeuralNetworkModel1(
#   (fc1): Linear(in_features=784, out_features=100, bias=True)
#   (BatchNorm1d2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=100, out_features=100, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=100, out_features=100, bias=True)
#   (BatchNorm1d1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
#summary(model, (1,28*28))

# %%
#  Instantiate loss class
criterion=nn.CrossEntropyLoss()

#  Instantiate optimizer class
learning_rate = 0.001
optimizer = torch.optim.Adamax(model.parameters())

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/025 | Batch 000/1200 | Cost: 2.4135
# Epoch: 001/025 | Batch 500/1200 | Cost: 0.6535
# Epoch: 001/025 | Batch 1000/1200 | Cost: 0.5050
# Epoch: 001/025 Train Cost: 0.3369
# Time elapsed: 0.23 min
# Epoch: 002/025 | Batch 000/1200 | Cost: 0.6091
# Epoch: 002/025 | Batch 500/1200 | Cost: 0.4359
# Epoch: 002/025 | Batch 1000/1200 | Cost: 0.4161
# Epoch: 002/025 Train Cost: 0.2935
# Time elapsed: 0.45 min
# Epoch: 003/025 | Batch 000/1200 | Cost: 0.5837
# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ### Model C: 5 Hidden Layers Feedforward Neural Network

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 64
n_iters = 9400
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 10

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %%
input_dim = 28*28
output_dim = 10
hidden_dim1 = 100 
hidden_dim2 = 100 
hidden_dim3 = 200 
hidden_dim4 = 300 
hidden_dim5 = 100

# %% [markdown]
# #### Create model class

# %%
class FNNModel2(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, hidden_dim5, output_dim):
        
        super(FNNModel2, self).__init__()
        
        self.f1 = nn.Linear(input_dim,hidden_dim1)
        self.BatchNorm1d1=nn.BatchNorm1d(hidden_dim1)
        self.relu1 = nn.ReLU()
        
        self.f2 = nn.Linear(hidden_dim1,hidden_dim2)
        self.relu2 = nn.ReLU()
        
        self.f3 = nn.Linear(hidden_dim2,hidden_dim3)
        self.tanh = nn.Tanh()
        
        self.f4 = nn.Linear(hidden_dim3,hidden_dim4)
        self.relu3 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.25)
        
        self.f5 = nn.Linear(hidden_dim4,hidden_dim5)
        self.BatchNorm1d2=nn.BatchNorm1d(hidden_dim5)
        self.relu4 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.2)
        
        self.f6 = nn.Linear(hidden_dim5,output_dim)
        
    def forward(self, x):
        out = self.f1(x)
        out = self.BatchNorm1d1(out)
        out = self.relu1(out)

        out = self.f2(out)
        out = self.relu2(out)
        
        out = self.f3(out)
        out = self.tanh(out)
        
        out = self.f4(out)
        out = self.relu3(out)
        out = self.dropout1(out)
        
        out = self.f5(out)
        out = self.BatchNorm1d2(out)
        out = self.relu4(out)
        out = self.dropout2(out)
        
        out = self.f6(out)
        
        return out

# %%
model = FNNModel2(input_dim, hidden_dim1, hidden_dim2, hidden_dim3, hidden_dim4, hidden_dim5, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FNNModel2(
#   (f1): Linear(in_features=784, out_features=100, bias=True)
#   (BatchNorm1d1): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (f2): Linear(in_features=100, out_features=100, bias=True)
#   (relu2): ReLU()
#   (f3): Linear(in_features=100, out_features=200, bias=True)
#   (tanh): Tanh()
#   (f4): Linear(in_features=200, out_features=300, bias=True)
#   (relu3): ReLU()
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (f5): Linear(in_features=300, out_features=100, bias=True)
#   (BatchNorm1d2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): ReLU()
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (f6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
#summary(model, (1,28*28))

# %%
criterion = nn.CrossEntropyLoss()

learning_rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.6)

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/010 | Batch 000/938 | Cost: 2.4586
# Epoch: 001/010 | Batch 500/938 | Cost: 0.4836
# Epoch: 001/010 Train Cost: 0.3703
# Time elapsed: 0.20 min
# Epoch: 002/010 | Batch 000/938 | Cost: 0.3019
# Epoch: 002/010 | Batch 500/938 | Cost: 0.5733
# Epoch: 002/010 Train Cost: 0.3863
# Time elapsed: 0.39 min
# Epoch: 003/010 | Batch 000/938 | Cost: 0.3728
# Epoch: 003/010 | Batch 500/938 | Cost: 0.3301
# Epoch: 003/010 Train Cost: 0.2889
# Time elapsed: 0.58 min
# Epoch: 004/010 | Batch 000/938 | Cost: 0.4510
# Epoch: 004/010 | Batch 500/938 | Cost: 0.2700
# Epoch: 004/010 Train Cost: 0.3016
# Time elapsed: 0.78 min
# Epoch: 005/010 | Batch 000/938 | Cost: 0.2780
# Epoch: 005/010 | Batch 500/938 | Cost: 0.3505
# Epoch: 005/010 Train Cost: 0.2700
# Time elapsed: 0.98 min
# Epoch: 006/010 | Batch 000/938 | Cost: 0.3885
# Epoch: 006/010 | Batch 500/938 | Cost: 0.1032
# Epoch: 006/010 Train Cost: 0.2699
# Time elapsed: 1.17 min
# Epoch: 007/010 | Batch 000/938 | Cost: 0.4011
# Epoch: 007/010 | Batch 500/938 | Cost: 0.2558
# Epoch: 007/010 Train Cost: 0.2375
# Time elapsed: 1.38 min
# Epoch: 008/010 | Batch 000/938 | Cost: 0.1676
# Epoch: 008/010 | Batch 500/938 | Cost: 0.4026
# Epoch: 008/010 Train Cost: 0.2289
# Time elapsed: 1.60 min
# Epoch: 009/010 | Batch 000/938 | Cost: 0.2736
# Epoch: 009/010 | Batch 500/938 | Cost: 0.1716
# Epoch: 009/010 Train Cost: 0.2156
# Time elapsed: 1.80 min
# Epoch: 010/010 | Batch 000/938 | Cost: 0.2196
# Epoch: 010/010 | Batch 500/938 | Cost: 0.3639
# Epoch: 010/010 Train Cost: 0.2171
# Time elapsed: 2.00 min
# Total Training Time: 2.00 min
# Training Accuracy: 92.11
# Test Accuracy: 88.38

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ### Model D: 3 Hidden Layers Feedforward Neural Network

# %% [markdown]
# #### Make dataset iterable

# %%
batch_size = 128
n_iters = 9400
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)
num_epochs
# Out:
# 20

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # create your dataloader

test_loader = DataLoader(test_dataset, batch_size=batch_size,  shuffle=False)

# %%
input_dim = 28*28
output_dim = 10
hidden_dim1 = 256
hidden_dim2 = 128

# %% [markdown]
# #### Create model class

# %%
class FNNModel3(nn.Module):
    def __init__(self, input_dim, hidden_dim1, hidden_dim2, output_dim):
        
        super(FNNModel3, self).__init__()
        
        self.f1 = nn.Linear(input_dim,hidden_dim1)
        self.BatchNorm1d1=nn.BatchNorm1d(hidden_dim1)
        self.relu1 = nn.ReLU()
        
        self.f2 = nn.Linear(hidden_dim1,hidden_dim2)
        self.BatchNorm1d2=nn.BatchNorm1d(hidden_dim2)
        self.relu2 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.3)
        
        self.f3 = nn.Linear(hidden_dim2,output_dim)
        
    def forward(self, x):
        out = self.f1(x)
        out = self.BatchNorm1d1(out)
        out = self.relu1(out)

        out = self.f2(out)
        out = self.BatchNorm1d2(out)
        out = self.relu2(out)
        out = self.dropout1(out)
        
        out = self.f3(out)
        
        return out

# %%
model = FNNModel3(input_dim, hidden_dim1, hidden_dim2, output_dim)

#######################
#  USE GPU FOR MODEL  #
#######################
model.to(device)
# Out:
# FNNModel3(
#   (f1): Linear(in_features=784, out_features=256, bias=True)
#   (BatchNorm1d1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (f2): Linear(in_features=256, out_features=128, bias=True)
#   (BatchNorm1d2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (f3): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
#summary(model, (1,28*28))

# %%
criterion = nn.CrossEntropyLoss()

learning_rate = 0.001
optimizer = torch.optim.Adamax(model.parameters())

# %% [markdown]
# #### Train the model

# %%
start_time = time.time()
minibatch_cost = []
epoch_cost = []
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, 28*28).to(device)
            
        ### FORWARD AND BACK PROP
        outputs = model(features)
        
        cost = criterion(outputs, targets)
        optimizer.zero_grad()
        
        cost.backward()
        minibatch_cost.append(cost)
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 500:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, num_epochs, batch_idx, 
                     len(train_loader), cost))
       
    model.eval()
    with torch.no_grad():
        cost = compute_loss(model, train_loader)
        epoch_cost.append(cost)
        print('Epoch: %03d/%03d Train Cost: %.4f' % (
                epoch+1, num_epochs, cost))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        
model.eval()
with torch.no_grad():
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))

    print('Training Accuracy: %.2f' % compute_accuracy(model, train_loader))
    print('Test Accuracy: %.2f' % compute_accuracy(model, test_loader))
# Out:
# Epoch: 001/020 | Batch 000/469 | Cost: 2.3862
# Epoch: 001/020 Train Cost: 0.3417
# Time elapsed: 0.16 min
# Epoch: 002/020 | Batch 000/469 | Cost: 0.3215
# Epoch: 002/020 Train Cost: 0.2946
# Time elapsed: 0.31 min
# Epoch: 003/020 | Batch 000/469 | Cost: 0.2720
# Epoch: 003/020 Train Cost: 0.2844
# Time elapsed: 0.46 min
# Epoch: 004/020 | Batch 000/469 | Cost: 0.2998
# Epoch: 004/020 Train Cost: 0.2536
# Time elapsed: 0.61 min
# Epoch: 005/020 | Batch 000/469 | Cost: 0.2466
# Epoch: 005/020 Train Cost: 0.2511
# Time elapsed: 0.76 min
# Epoch: 006/020 | Batch 000/469 | Cost: 0.2597
# Epoch: 006/020 Train Cost: 0.2204
# Time elapsed: 0.91 min
# Epoch: 007/020 | Batch 000/469 | Cost: 0.1734
# Epoch: 007/020 Train Cost: 0.2106
# Time elapsed: 1.07 min
# Epoch: 008/020 | Batch 000/469 | Cost: 0.2171
# Epoch: 008/020 Train Cost: 0.2254
# Time elapsed: 1.22 min
# Epoch: 009/020 | Batch 000/469 | Cost: 0.2218
# Epoch: 009/020 Train Cost: 0.2048
# Time elapsed: 1.37 min
# Epoch: 010/020 | Batch 000/469 | Cost: 0.1730
# Epoch: 010/020 Train Cost: 0.1714
# Time elapsed: 1.52 min
# Epoch: 011/020 | Batch 000/469 | Cost: 0.1249
# Epoch: 011/020 Train Cost: 0.1696
# Time elapsed: 1.67 min
# Epoch: 012/020 | Batch 000/469 | Cost: 0.1858
# Epoch: 012/020 Train Cost: 0.1617
# Time elapsed: 1.83 min
# Epoch: 013/020 | Batch 000/469 | Cost: 0.1461
# Epoch: 013/020 Train Cost: 0.1510
# Time elapsed: 1.98 min
# Epoch: 014/020 | Batch 000/469 | Cost: 0.1095
# Epoch: 014/020 Train Cost: 0.1939
# Time elapsed: 2.14 min
# Epoch: 015/020 | Batch 000/469 | Cost: 0.1678
# Epoch: 015/020 Train Cost: 0.1556
# Time elapsed: 2.31 min
# Epoch: 016/020 | Batch 000/469 | Cost: 0.1459
# Epoch: 016/020 Train Cost: 0.1480
# Time elapsed: 2.48 min
# Epoch: 017/020 | Batch 000/469 | Cost: 0.2715
# Epoch: 017/020 Train Cost: 0.1335
# Time elapsed: 2.66 min
# Epoch: 018/020 | Batch 000/469 | Cost: 0.1899
# Epoch: 018/020 Train Cost: 0.1161
# Time elapsed: 2.84 min
# Epoch: 019/020 | Batch 000/469 | Cost: 0.2126
# Epoch: 019/020 Train Cost: 0.1191
# Time elapsed: 3.00 min
# Epoch: 020/020 | Batch 000/469 | Cost: 0.1352
# Epoch: 020/020 Train Cost: 0.1230
# Time elapsed: 3.16 min
# Total Training Time: 3.16 min
# Training Accuracy: 95.23
# Test Accuracy: 88.55

# %%
#Plot the loss curve

plt.figure(figsize=(8,5))
plt.plot(range(len(epoch_cost)), epoch_cost)
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.title("Loss of training")
plt.show()

# %% [markdown]
# ## Results of regularizations
#
# | Model Name                    | Training Accuracy | Test Accuracy | Training Accuracy(Dropout) | Test Accuracy(Dropout) |
# |--------------------------------|----------|----------|----------|----------|
# | Model B |  92.20  |  87.53  |  90.30   |  87.09   |
# | Model C |  87.74  |  85.76  |  88.98   |  86.54   |
# | Model D |  90.90  |  86.56  |  89.48   |  86.57   |

# %% [markdown]
# ## Results of optimizations (Test accuracy)
# - With dropouts from the regularization part
# - Best optimizer for each model is bolded
#
# | Optimizer                    | Model B | Model C | Model D |
# |--------------------------------|----------|----------|----------|
# | SGD |  87.09  |  85.11  |  86.44  |
# | **SGD Momentum** |  87.27  |  **85.46**  |  87.61   |
# | SGD Nesterov |  87.33  |  85.12  |  87.64   |
# | Adam |  86.86  |  10.00  |   86.74  |
# | Adagrad |  87.63  |  80.76  |   86.42  |
# | Adadelta |  83.92  |  80.15  |  81.50   |
# | **Adamax** |  **87.91**  |  84.82  |  **87.98**   |
# | RMSProp |  85.66  |  10.00  |  86.03  |
#
#
# ### Batch normalozation
# - With dropouts from the regularization part
# - We employed the best optimizer for the models from the previous table
#
# | Model Name | Optimizer| Training Accuracy | Test Accuracy |
# |------------|----------|----------|----------|
# | Model B |  Adamax  |  95.55  | 89.25  |
# | Model C |  SGD Momentum  |  92.11  |  88.38  |
# | Model D |  Adamax  |  95.23  |  88.55  |
