# %% [markdown]
# ### Assignment Set 1 by [Zahra Taheri](https://github.com/zahta) for Deep Learning Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn
import torch

# %%
print("Scikit-learn Version: ", sklearn.__version__)
print("PyTorch Version: ", torch.__version__)
# Out:
# Scikit-learn Version:  0.23.1
# PyTorch Version:  1.6.0

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 5 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100
plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('A')
plt.ylabel('B')
plt.show()
df = pd.DataFrame(np.random.randn(10, 5)) 
print(df)
j=np.pi
for i in range(100000000):
  j+=j    
print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3         4
# 0  0.815327 -1.058642 -0.580161  0.625116  0.356257
# 1 -0.120238  0.232654  1.878934 -0.096913 -0.591658
# 2  0.056036 -2.157437  1.178780  1.284325 -1.045558
# 3 -0.108734  0.436501 -0.221574 -0.169526  0.440763
# 4  1.160937 -1.168190  1.945897 -0.006989  1.393997
# 5 -0.750471 -0.278462  2.242595  0.859534 -0.125011
# 6  1.489240  0.343142 -0.212383 -0.721516  1.386634
# 7  1.118214 -0.606586  1.313765  1.143020 -0.237702
# 8  1.682927 -0.799188  0.065487 -1.375333 -1.584555
# 9 -1.053759  0.288570 -0.006056  1.708027 -0.843828
#
# -> Execution Time = 17.607656002044678 in Seconds <-

# %%
import tensorflow as tf
print("TensorFlow Version: ", tf.__version__)
# Out:
# TensorFlow Version:  2.1.0
